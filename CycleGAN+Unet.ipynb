# %%
# !git clone https://github.com/SnehamayRoy/CycleGAN-Unet.git
# Out:
# Cloning into 'CycleGAN-Unet'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 67 (delta 2), reused 67 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 18.77 MiB | 24.39 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !kaggle datasets download -d snehamayroy/cyclegan ## My dataset setup, used for training(1500 images)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/snehamayroy/cyclegan
# License(s): other
# ...
#  21% 7.00M/32.7M [00:00<00:00, 52.8MB/s]
# 100% 32.7M/32.7M [00:00<00:00, 143MB/s]

# %%
# !unzip cyclegan.zip
# Out:
# Archive:  cyclegan.zip
#   inflating: data/expertc/a0001-jmac_DSC1459.jpg
#   inflating: data/expertc/a0002-dgw_005.jpg
#   inflating: data/expertc/a0003-NKIM_MG_8178.jpg
#   inflating: data/expertc/a0004-jmac_MG_1384.jpg
#   inflating: data/expertc/a0005-jn_2007_05_10__564.jpg
#   inflating: data/expertc/a0006-IMG_2787.jpg
#   inflating: data/expertc/a0007-IMG_2480.jpg
#   inflating: data/expertc/a0008-WP_CRW_3959.jpg
#   inflating: data/expertc/a0009-kme_372.jpg
#   inflating: data/expertc/a0010-jmac_MG_4807.jpg
#   inflating: data/expertc/a0011-DSC_0082.jpg
#   inflating: data/expertc/a0012-kme_143.jpg
#   inflating: data/expertc/a0013-MB_20030906_001.jpg
#   inflating: data/expertc/a0014-WP_CRW_6320.jpg
#   inflating: data/expertc/a0015-DSC_0081.jpg
#   inflating: data/expertc/a0016-jmac_MG_0795.jpg
#   inflating: data/expertc/a0017-050710_031618__MG_3496.jpg
#   inflating: data/expertc/a0018-kme_234.jpg
#   inflating: data/expertc/a0019-jmac_MG_0653.jpg
# ...

# %%
# %cd /content/CycleGAN-Unet
# Out:
# /content/CycleGAN-Unet

# %%
# !mv /content/CycleGAN-Unet/data/train/expertc /content/CycleGAN-Unet/data/train/ex2

# %%
# !mv /content/CycleGAN-Unet/data/train/original /content/CycleGAN-Unet/data/train/ori2

# %%
# !mv /content/data/original /content/CycleGAN-Unet/data/train/original

# %%
# !mv /content/data/expertc /content/CycleGAN-Unet/data/train/expertc

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !mkdir -p /content/CycleGAN-Unet/saved_images

# %%
# !python train.py
# Out:
# 2025-02-17 12:14:15.756632: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739794455.776860    6180 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739794455.783015    6180 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-17 12:14:15.803177: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %reload_ext tensorboard

# %%
# %tensorboard --logdir runs --port 5005
